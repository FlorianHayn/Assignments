# %%
#Algorithms - Warmup - Solve me first

def solveMeFirst(a,b):
    return a + b


num1 = int(input())
num2 = int(input())
res = solveMeFirst(num1,num2)
print(res)

# %%
#Warumup - Simple Array Sum
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'simpleArraySum' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY ar as parameter.
#

def simpleArraySum(ar):
    result = 0
    for i in range(ar_count):
        result += ar[i]
    return result
        

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    ar_count = int(input().strip())

    ar = list(map(int, input().rstrip().split()))

    result = simpleArraySum(ar)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
# Warmup - Compare the triplets
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'compareTriplets' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER_ARRAY a
#  2. INTEGER_ARRAY b
#

def compareTriplets(a, b):
    comparisonPoints = [0, 0]
    for i in range(len(a)):
        if a[i] > b[i]:
            comparisonPoints[0] += 1
        elif a[i] < b[i]:
            comparisonPoints[1] += 1
        else:
            continue
    return comparisonPoints

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    a = list(map(int, input().rstrip().split()))

    b = list(map(int, input().rstrip().split()))

    result = compareTriplets(a, b)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %%
#Warmup - A very big sum
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'aVeryBigSum' function below.
#
# The function is expected to return a LONG_INTEGER.
# The function accepts LONG_INTEGER_ARRAY ar as parameter.
#

def aVeryBigSum(ar):
    res = 0
    for i in range(ar_count):
        res += ar[i]
    return res

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    ar_count = int(input().strip())

    ar = list(map(int, input().rstrip().split()))

    result = aVeryBigSum(ar)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Warmup - Diagonal difference
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'diagonalDifference' function below.
#
# The function is expected to return an INTEGER.
# The function accepts 2D_INTEGER_ARRAY arr as parameter.
#

def diagonalDifference(arr):
    sumLowerStart = 0
    sumUpperStart = 0
    for i in range(n):
        sumUpperStart += arr[-(i+1)][i]
        sumLowerStart += arr[i][i]
    return abs(sumUpperStart - sumLowerStart)

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    result = diagonalDifference(arr)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Warmup - PlusMinus
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'plusMinus' function below.
#
# The function accepts INTEGER_ARRAY arr as parameter.
#

def plusMinus(arr):
    pos = 0
    neg = 0
    null = 0
    for i in range(n):
        if arr[i] < 0:
            neg += 1
        elif arr[i] > 0:
            pos += 1
        elif arr[i] == 0:
            null += 1
    print("{:.6f}".format(pos / n, 6))
    print("{:.6f}".format(neg / n, 6))
    print("{:.6f}".format(null / n, 6))

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    plusMinus(arr)

# %%
#Warmup - Staircase
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'staircase' function below.
#
# The function accepts INTEGER n as parameter.
#

def staircase(n):
    for i in range(n):
        print(" "*(n-1-i) + "#"*(i+1))

if __name__ == '__main__':
    n = int(input().strip())

    staircase(n)

# %%
#Warmup - Minimax Sum
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'miniMaxSum' function below.
#
# The function accepts INTEGER_ARRAY arr as parameter.
#

def miniMaxSum(arr):
    highest = arr[0]
    lowest = arr[0]
    sumArr = 0
    for i in range(1, len(arr)):
        if arr[i] < lowest:
            lowest = arr[i]
        elif arr[i] > highest:
            highest = arr[i]
        else:
            continue
    for i in range(len(arr)):
        sumArr += arr[i]
    sumLowest = sumArr - highest
    sumHighest = sumArr - lowest
    print(sumLowest, sumHighest)

if __name__ == '__main__':

    arr = list(map(int, input().rstrip().split()))

    miniMaxSum(arr)

# %%
#Warmup - Birthday cake candles
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'birthdayCakeCandles' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY candles as parameter.
#

def birthdayCakeCandles(candles):
    highest = candles[0]
    countHighest = 0
    for i in range(1, len(candles)):
        if candles[i] > highest:
            highest = candles[i]
        else:
            continue
    for i in range(len(candles)):
        if candles[i] == highest:
            countHighest += 1
    return countHighest

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    candles_count = int(input().strip())

    candles = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(candles)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Warmup - TimeConversion
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'timeConversion' function below.
#
# The function is expected to return a STRING.
# The function accepts STRING s as parameter.
#

def timeConversion(s):
    hour = int(s[:2])
    timeWithoutHour = s[2:-2]
    convertedTime = ""
    if hour == 12 and s[-2] == "A":
        convertedTime = "00" + timeWithoutHour
    elif hour == 12 and s[-2] == "P":
        convertedTime = "12" + timeWithoutHour
    else:
        if s[-2] == "A":
            convertedTime = s[:-2]
        elif s[-2] == "P":
            newHour = hour + 12
            convertedTime = str(newHour) + timeWithoutHour
    return convertedTime

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = timeConversion(s)

    fptr.write(result + '\n')

    fptr.close()

# %%
#Sorting - Intro to tutorial challenges
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'introTutorial' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. INTEGER V
#  2. INTEGER_ARRAY arr
#

def introTutorial(V, arr):
    loc = 0
    for i in range(len(arr)):
        if V == arr[i]:
            loc = i
            break
    return loc
            

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    V = int(input().strip())

    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    result = introTutorial(V, arr)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Sorting - Insertion sort part 1
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort1' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort1(n, arr):
    number = arr[-1]
    change = False
    for i in range(n):
        if number < arr[-i - 1]:
            arr[-i] = arr[-i - 1]
            print(*arr)
        elif number > arr[-i - 1]:
            arr[-i] = number
            print(*arr)
            change = True
            break
    if change == False:
        arr[0] = number
        print(*arr)
        


if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort1(n, arr)

# %%
#Sorting - Insertion sort part 2
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort2' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort2(n, arr):
    for list_iter in range(1, n):
        for scan in range(list_iter):
            if arr[scan] > arr[list_iter]:
                temp = arr[scan]
                arr[scan] = arr[list_iter]
                arr[list_iter] = temp
        print(*arr)
        
if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort2(n, arr)

# %%
#Sorting - big sorting
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'bigSorting' function below.
#
# The function is expected to return a STRING_ARRAY.
# The function accepts STRING_ARRAY unsorted as parameter.
#

def bigSorting(unsorted):
    unsorted.sort(key=int)    
    return unsorted

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    unsorted = []

    for _ in range(n):
        unsorted_item = input()
        unsorted.append(unsorted_item)

    result = bigSorting(unsorted)

    fptr.write('\n'.join(result))
    fptr.write('\n')

    fptr.close()

# %%
#Sorting - correctness and loop invariant

def insertion_sort(l):
    for i in range(1, len(l)):
        j = i-1
        key = l[i]
        while (j >= 0) and (l[j] > key):
           l[j+1] = l[j]
           j -= 1
        l[j+1] = key

m = int(input().strip())
ar = [int(i) for i in input().strip().split()]
insertion_sort(ar)
print(" ".join(map(str,ar)))

# %%
#Sorting - Quicksort 1 Partition
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'quickSort' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts INTEGER_ARRAY arr as parameter.
#

def quickSort(arr):
    left = []
    equal = []
    right = []
    pivot = arr[0]

    for element in arr:
        if element < pivot:
            left.append(element)
        elif element == pivot:
            equal.append(element)
        else:
            right.append(element)

    final_array = (*left, *equal, *right)
    return final_array

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    result = quickSort(arr)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %%
#Sorting - Counting sort 2
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'countingSort' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts INTEGER_ARRAY arr as parameter.
#

def countingSort(arr):
    frequency_array = []
    len_array = len(arr)
    sorted_array = []
    for i in range(100):
        frequency_array.append(0)

    for i in range(len_array):
        frequency_array[arr[i]] += 1

    for i in range(100):
        for n in range(frequency_array[i]):
            sorted_array.append(i)

    return sorted_array

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    result = countingSort(arr)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %%
#orting - counting sort 1
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'countingSort' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts INTEGER_ARRAY arr as parameter.
#

def countingSort(arr):
    frequency_array = []
    len_array = len(arr)
    for i in range(100):
        frequency_array.append(0)

    for i in range(len_array):
        frequency_array[arr[i]] += 1

    return frequency_array

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    result = countingSort(arr)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %%
#Sorting - closest numbers
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'closestNumbers' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts INTEGER_ARRAY arr as parameter.
#

def closestNumbers(arr):

    list_min_distance = []
    
    arr.sort()
    min_distance = 9999999999

    for i in range(n - 1):
        old_min_distance = min_distance

        if arr[i + 1] - arr[i] <= min_distance:
            min_distance = arr[i + 1] - arr[i]
            if min_distance == old_min_distance:
                list_min_distance.append(arr[i])
                list_min_distance.append(arr[i + 1])
            elif min_distance < old_min_distance:
                list_min_distance = [arr[i], arr[i + 1]]
                                         

    return list_min_distance

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    result = closestNumbers(arr)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %%
#Sorting - Find the Median
def findMedian(arr):
    median_pos = n // 2
    for list_iter in range(1, n):
        for scan in range(list_iter):
            if arr[scan] > arr[list_iter]:
                temp = arr[scan]
                arr[scan] = arr[list_iter]
                arr[list_iter] = temp

    return arr[median_pos]

# %%
#String - Super reduced string
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'superReducedString' function below.
#
# The function is expected to return a STRING.
# The function accepts STRING s as parameter.
#

def superReducedString(s):
    
    stringAsList = list(s)
    lenList = len(stringAsList)
    i = 0
    
    while i < lenList - 1:
        if stringAsList[i] == stringAsList[i + 1]:
            del stringAsList[i : i + 2]
            i = 0
            lenList -= 2
        else:
            i += 1
            
    if stringAsList != []:        
        return "".join(stringAsList)
    else:
        return "Empty String"

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = superReducedString(s)

    fptr.write(result + '\n')

    fptr.close()

# %%
#String - CamelCase
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'camelcase' function below.
#
# The function is expected to return an INTEGER.
# The function accepts STRING s as parameter.
#

def camelcase(s):
    counter = 1
    for letter in s:
        if letter.isupper() == True:
            counter += 1
    return counter

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = camelcase(s)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#String - Strong Password
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'minimumNumber' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. INTEGER n
#  2. STRING password
#

def minimumNumber(n, password):
    
    numbers = "0123456789"
    lower_case = "abcdefghijklmnopqrstuvwxyz"
    upper_case = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    special_characters = "!@#$%^&*()-+"
        
    numberChange = False
    lowerChange = False
    upperChange = False
    specialChange = False

    falseCount = 4
    
    for element in password:
        if element in numbers and numberChange == False:
            falseCount -= 1
            numberChange = True
        elif element in lower_case and lowerChange == False:
            falseCount -= 1
            lowerChange = True
        elif element in upper_case and upperChange == False:
            falseCount -= 1
            upperChange = True
        elif element in special_characters and specialChange == False:
            falseCount -= 1
            specialChange = True
    if n >= 6:
        return falseCount
    elif n < 6:
        if n + falseCount >= 6:
            return falseCount
        else:
            return 6 - n
        
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    password = input()

    answer = minimumNumber(n, password)

    fptr.write(str(answer) + '\n')

    fptr.close()

# %%
#String - Pangram
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'pangrams' function below.
#
# The function is expected to return a STRING.
# The function accepts STRING s as parameter.
#

def pangrams(s):
    listOfLetters = []
    counter = 0
    for letter in s:
        letter = letter.lower()
        if letter == " ":
            continue
        if letter not in listOfLetters:
            counter += 1
            listOfLetters.append(letter)
    if counter == 26:
        return "pangram"
    else:
        return "not pangram"

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = pangrams(s)

    fptr.write(result + '\n')

    fptr.close()

# %%
#String - alternating characters 
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'alternatingCharacters' function below.
#
# The function is expected to return an INTEGER.
# The function accepts STRING s as parameter.
#

def alternatingCharacters(s):
    for i in range(q):
        position = 0
        lenString = len(s)
        stringAsList = list(s)
        counterDeletions = 0
    
        while position < lenString - 1:
            if stringAsList[position] == stringAsList[position + 1]:
                counterDeletions += 1
                position += 1
            else:
                position += 1
            
        return counterDeletions
    
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input().strip())

    for q_itr in range(q):
        s = input()

        result = alternatingCharacters(s)

        fptr.write(str(result) + '\n')

    fptr.close()
